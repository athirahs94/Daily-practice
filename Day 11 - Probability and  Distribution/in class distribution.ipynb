# %% [markdown]
# Distribution
# - how the frequency of somthing is distributed.
#
# - That if you take a **sample size**of 100 people
#
# - I want to know how tall the people of Kuala Lumpur, ages between 18 to 45
#
# - selecting sample size : 7 mil - 100k

# %% [markdown]
# # AI Ethics
#
# - data privacy - anonimity
# - data transparency - how are using the data

# %%
import seaborn as sns

# %%
import pandas as pd

df = pd.DataFrame(data)

# %%
data = {
    'name':['idress','hazirah','athirah','mel','nazri','ibrahim','amin'],
    'age':[29,24,31,27,20,18,27],
    'height' :[185,152,163,162,164,168,168],
    'gender':['m','f','f','f','m','m','m'],
    'ethnicity':['kashmiri','malay','malay','malay','malay','malay','malay']
}

# %%
sns.histplot(df, x = 'name',y='height')

plt.title('Height of the people')
plt.xlabel('name')
plt.ylabel("height")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 3
#       1 sns.histplot(df, x = 'name',y='height')
# ----> 3 plt.title('Height of the people')
#       4 plt.xlabel('name')
#       5 plt.ylabel("height")
#
# NameError: name 'plt' is not defined

# %%
sns.histplot(data=df, x ='height')
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
e_malay = df.ethnicity('malay')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 e_malay = df.ethnicity('malay')
#
# TypeError: 'Series' object is not callable

# %%
malay = df
df
# Out:
#       name  age  height gender ethnicity
# 0   idress   25     185      m  kashmiri
# 1  hazirah   25     152      f     malay
# 2  athirah   25     163      f     malay
# 3      mel   25     162      f     malay
# 4    nazri   25     164      m     malay
# 5  ibrahim   25     168      m     malay
# 6     amin   25     168      m     malay

# %%
e_malay =df[df['ethnicity'] == 'malay']
print ('Name list Malay etnicity')
print(e_malay)
# Out:
# Name list Malay etnicity
#       name  age  height gender ethnicity
# 1  hazirah   25     152      f     malay
# 2  athirah   25     163      f     malay
# 3      mel   25     162      f     malay
# 4    nazri   25     164      m     malay
# 5  ibrahim   25     168      m     malay
# 6     amin   25     168      m     malay

# %%
female =df[df['gender'] == 'f']
print ('Name list gender Female')
print(e_malay)
# Out:
# Name list gender Female
#       name  age  height gender ethnicity
# 1  hazirah   25     152      f     malay
# 2  athirah   25     163      f     malay
# 3      mel   25     162      f     malay

# %%
malayOver21 = df[(df['ethnicity'] == 'malay')  & (df['age'] > 21)]
print(malayOver21)
# Out:
#       name  age  height gender ethnicity
# 1  hazirah   25     152      f     malay
# 2  athirah   25     163      f     malay
# 3      mel   25     162      f     malay
# 4    nazri   25     164      m     malay
# 5  ibrahim   25     168      m     malay
# 6     amin   25     168      m     malay

# %%
# Filter rows where 'Age' is greater than 28
filtered_df = df[df['Age'] > 28]
print("Filtered by Age > 28:")
print(filtered_df)

# Filter rows where 'City' is 'New York'
filtered_df_city = df[df['City'] == 'New York']
print("\nFiltered by City == 'New York':")
print(filtered_df_city)

# %%
tipsdf = sns.load_dataset('tips')

tipsdf.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# #create these dataframe
# 1. only male
# 2. tips above 6 doller
# 3. smokers dining on sunday

# %%
male =tipsdf[tipsdf['sex'] == 'Male']
print ('List of the male')
print(male)
# Out:
# List of the male
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]

# %%
tipOver6 = tipsdf[tipsdf['tip'] > 6]
print(tipOver6)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3

# %%
smoker_sunday = tipsdf[(tipsdf['smoker'] == 'Yes')  & (tipsdf['day'] == 'Sun') &  (tipsdf['time'] == 'Dinner')]
print(smoker_sunday)
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 164       17.51  3.00  Female    Yes  Sun  Dinner     2
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2
# 173       31.85  3.18    Male    Yes  Sun  Dinner     2
# 174       16.82  4.00    Male    Yes  Sun  Dinner     2
# 175       32.90  3.11    Male    Yes  Sun  Dinner     2
# 176       17.89  2.00    Male    Yes  Sun  Dinner     2
# 177       14.48  2.00    Male    Yes  Sun  Dinner     2
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2
# 179       34.63  3.55    Male    Yes  Sun  Dinner     2
# 180       34.65  3.68    Male    Yes  Sun  Dinner     4
# 181       23.33  5.65    Male    Yes  Sun  Dinner     2
# 182       45.35  3.50    Male    Yes  Sun  Dinner     3
# 183       23.17  6.50    Male    Yes  Sun  Dinner     4
# 184       40.55  3.00    Male    Yes  Sun  Dinner     2
# 186       20.90  3.50  Female    Yes  Sun  Dinner     3
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5
# ...

# %% [markdown]
# - Checking the distribution of data in our dataset
#
# - or how many datapoints, there are male or female?
# - how manyfor each day of the week?
# - how many for each ethnicity

# %% [markdown]
# - checking if we can rely on data
# - looking at sample size to check for anything out of ordinary
#
# we study distribution in ML, because class distribution influence the output of AI Models
#
# - very simple example : Case study :
# - a company in US. Security
# - they wanted to create a tool, that would screen criminals?
# - just by looking at facethat somebody is a criminal?
#
# - there should be database. there should be data
#
# - more example of black people, in their database base along with the crimes that they had committed.
#
# - 1000 african american criminal cases
# - 100 white hispanic
#
# - data to an AI Model, will always be correct when labelling a africanamerican as a criminal?
#
# - it lead to false arrests
#
# ** class imbalance**
#
# - if there is more data related to one class compared to the other
