# %% [markdown]
# Probability
# - Likelihood of something
# - chance of  something to happen
#
# - Why on earth do we need to study probability in an AI ML class
#     - for machine learning - because machine will be predicting - for future
#     - help to forcast something based on the data
#
#     - ML - machine to give output (any kind of machine). YES or NO
#     - Not just output
#     -
#     - machine calculated the possibility of an answer
#     - 100% confidence
#     we do not used just if and else :
#     ML model calculate possibilities
#     how to calculate these. Probability and distribution

# %% [markdown]
# - One simple example :
# Cats and dog AI ML

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# how many unique values do you see in all the column, and what you can infer
# what is the average bill amount
# what is the average tips amount
#just find some new insigtht

# %%
#numerical - where you have number, interger, float

#categorical - in whcih you have classes / group of things

# %%
# unique values

df['sex'].unique()
# Out:
# ['Female', 'Male']
# Categories (2, object): ['Male', 'Female']

# %%
df['smoker'].unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['Yes', 'No']

# %%
df['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
df['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
#average bill amount

df['total_bill'].mean()

avg_total_bill = df['total_bill'].mean()
print(avg_total_bill)
# Out:
# 19.78594262295082

# %%
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
#average tip amount
df['tip'].mean()

avg_tip = df['tip'].mean()
print(avg_tip)
# Out:
# 2.99827868852459

# %%
df['tip'].mean()
# Out:
# np.float64(2.99827868852459)

# %%
#check, how many rich or generous people come to u=our restaurant
#what is

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
count

# %%
count = df['size'].value_counts()

plt.bar(df['size'],count)

# %%
counts = df['size'].value_counts()

plt.bar(df['size'],counts)


plt.xlabel("size")
plt.ylabel("count")
plt.title("The total or people come per group")

plt.xticks(rotation=45, ha='right') # Rotate x-axis labels if they overlap
plt.tight_layout()

plt.show()

# %%
counts = df['size'].value_counts()


plt.bar(counts.index, counts.values)

plt.xlabel("size")
plt.ylabel("count")
plt.title("The total of people per group")

plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
counts = df['size'].value_counts()
size_people = df['size'].unique()


plt.bar(size_people, counts)

plt.xlabel("size")
plt.ylabel("count")
plt.title("The total of people per group")

plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %%
#crate

x=df['size'].unique()
y=df['size'].value_counts()

plt.bar(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
y = df['size'].value_counts()
x = df['size'].unique()
 
sns.barplot(y=y,x=x)
# Out:
# <Axes: ylabel='count'>

# %%
y = df['size'].value_counts()
x = df['size'].unique()
 
sns.barplot(y=y,x=x)
# Out:
# <Axes: ylabel='count'>

# %%
seriestime=df['time'].value_counts()
seriestime
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
sns.histplot(df, df['size'].unique(), df['size'].value_counts(),kde=True)
# Out:
# CategoricalIndex(['Dinner', 'Lunch'], categories=['Lunch', 'Dinner'], ordered=False, dtype='category', name='time')

# %%
sns.histplot(df, x = 'size',kde=True)

plt.title('Data Distribution')
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
y = df['tip'].value_counts()
x = df['tip'].unique()
 
plt.bar(x,y)
# Out:
# <BarContainer object of 123 artists>

# %%
sns.histplot(df, x = 'tip',kde=True)

plt.title('Data Distribution')
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(df, x = 'total_bill')

plt.title('Data Distribution')
plt.xlabel("total_bill'")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Exercise 1 - Add tip percentage
# 1. create new column :
# tip_pct = tip/total_bill *100
# 2.Compute correlation of tip_pct with total_bill and with size
# 3. Look at the heatmap again. What change?

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df['tip_pct'] = ((df['tip'] / df['total_bill'])*100).round(2)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  tip_pct
# 0         16.99  1.01  Female     No   Sun  Dinner     2     5.94
# 1         10.34  1.66    Male     No   Sun  Dinner     3    16.05
# 2         21.01  3.50    Male     No   Sun  Dinner     3    16.66
# 3         23.68  3.31    Male     No   Sun  Dinner     2    13.98
# 4         24.59  3.61  Female     No   Sun  Dinner     4    14.68
# ..          ...   ...     ...    ...   ...     ...   ...      ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    20.39
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     7.36
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     8.82
# 242       17.82  1.75    Male     No   Sat  Dinner     2     9.82
# 243       18.78  3.00  Female     No  Thur  Dinner     2    15.97
#
# [244 rows x 8 columns]

# %%
df['New column']=None
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  tip_pct New column
# 0         16.99  1.01  Female     No   Sun  Dinner     2     5.94       None
# 1         10.34  1.66    Male     No   Sun  Dinner     3    16.05       None
# 2         21.01  3.50    Male     No   Sun  Dinner     3    16.66       None
# 3         23.68  3.31    Male     No   Sun  Dinner     2    13.98       None
# 4         24.59  3.61  Female     No   Sun  Dinner     4    14.68       None
# ..          ...   ...     ...    ...   ...     ...   ...      ...        ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    20.39       None
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     7.36       None
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     8.82       None
# 242       17.82  1.75    Male     No   Sat  Dinner     2     9.82       None
# 243       18.78  3.00  Female     No  Thur  Dinner     2    15.97       None
#
# [244 rows x 9 columns]

# %%
df[['tip_pct','total_bill','size']].cov().round(2)

co_df =['tip_pct','total_bill','size']
covariance_df = df[co_df].cov()
covariance_df.round(2)
# Out:
#             tip_pct  total_bill  size
# tip_pct       37.30      -18.41 -0.83
# total_bill   -18.41       79.25  5.07
# size          -0.83        5.07  0.90

# %%
correlation_tip = df[co_tip].corr().round(2)
correlation_tip
# Out:
#              tip  total_bill  size
# tip         1.00        0.68  0.49
# total_bill  0.68        1.00  0.60
# size        0.49        0.60  1.00

# %%
sns.heatmap(correlation_tip, cmap='Blues',annot=True)
# Out:
# <Axes: >

# %%
df2 = df.drop(columns=['New column'])

# %%
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size  tip_pct
# 0         16.99  1.01  Female     No   Sun  Dinner     2     5.94
# 1         10.34  1.66    Male     No   Sun  Dinner     3    16.05
# 2         21.01  3.50    Male     No   Sun  Dinner     3    16.66
# 3         23.68  3.31    Male     No   Sun  Dinner     2    13.98
# 4         24.59  3.61  Female     No   Sun  Dinner     4    14.68
# ..          ...   ...     ...    ...   ...     ...   ...      ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    20.39
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     7.36
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     8.82
# 242       17.82  1.75    Male     No   Sat  Dinner     2     9.82
# 243       18.78  3.00  Female     No  Thur  Dinner     2    15.97
#
# [244 rows x 8 columns]
